# %% [markdown]
# # 🧱 03 — Construction des datamarts

# %%
import sys
sys.path.append('..')

from src.data_loader import load_processed, save_datamart
from src.datamarts import build_all

df = load_processed()
dms = build_all(df)
print('Datamarts :', list(dms.keys()))

# %% [markdown]
# ## KPIs globaux

# %%
dms['global_kpis'].T

# %% [markdown]
# ## Performance par marque

# %%
dms['brand_performance']

# %% [markdown]
# ## Performance par pays

# %%
dms['country_performance']

# %% [markdown]
# ## Performance par canal

# %%
dms['channel_performance']

# %% [markdown]
# ## Évolution mensuelle

# %%
dms['monthly_trend']

# %% [markdown]
# ## Sauvegarde

# %%
for name, dm in dms.items():
    path = save_datamart(dm, name)
    print(f'✓ {path.name}')
